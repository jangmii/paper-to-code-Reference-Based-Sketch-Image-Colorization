# %%
import os
os.chdir("/content/drive/MyDrive/paper-to-code-Reference-Based-Sketch-Image-Colorization-master")

# !git init

# !git config --global user.email "0310_rose@naver.com"
# !git config --global user.name "jangmii"

# !git add .
# !git commit -m "colab"

#!git remote add origin https://jangmii:429412k!@github.com/jangmii/paper-to-code-Reference-Based-Sketch-Image-Colorization.git
# !git remote rm origin
# !git remote add origin https://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@github.com/jangmii/paper-to-code-Reference-Based-Sketch-Image-Colorization.git
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/paper-to-code-Reference-Based-Sketch-Image-Colorization-master/.git/
# [master 902db4d] colab
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite github.ipynb (80%)

# %%
# !git add .
# !git commit -m "colab"
# !git pull origin master --allow-unrelated-histories
# !git push origin master
# Out:
# [master 34faa0c] colab
#  1 file changed, 1 insertion(+), 1 deletion(-)
# From https://github.com/jangmii/paper-to-code-Reference-Based-Sketch-Image-Colorization
#  * branch            master     -> FETCH_HEAD
# Auto-merging train.py
# CONFLICT (add/add): Merge conflict in train.py
# Auto-merging run.ipynb
# CONFLICT (add/add): Merge conflict in run.ipynb
# Automatic merge failed; fix conflicts and then commit the result.
# To https://github.com/jangmii/paper-to-code-Reference-Based-Sketch-Image-Colorization.git
#  ! [rejected]        master -> master (non-fast-forward)
# error: failed to push some refs to 'https://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@github.com/jangmii/paper-to-code-Reference-Based-Sketch-Image-Colorization.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# ...
