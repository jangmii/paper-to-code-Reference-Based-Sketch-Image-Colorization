# %%
import os
os.chdir("/content/drive/MyDrive/paper-to-code-Reference-Based-Sketch-Image-Colorization-master")

# !git init

# !git config --global user.email "0310_rose@naver.com"
# !git config --global user.name "jangmii"

# !git add .
# !git commit -m "colab"

#!git remote add origin https://jangmii:429412k!@github.com/jangmii/paper-to-code-Reference-Based-Sketch-Image-Colorization.git
# !git remote add origin https://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@github.com/jangmii/{repository}.git
# Out:
# Initialized empty Git repository in /content/drive/MyDrive/paper-to-code-Reference-Based-Sketch-Image-Colorization-master/.git/
# [master (root-commit) 4123dd9] colab
#  26 files changed, 1082 insertions(+)
#  create mode 100644 README.md
#  create mode 100644 __pycache__/dataset.cpython-37.pyc
#  create mode 100644 __pycache__/dataset.cpython-38.pyc
#  create mode 100644 __pycache__/encoder.cpython-38.pyc
#  create mode 100644 __pycache__/model.cpython-37.pyc
#  create mode 100644 __pycache__/model.cpython-38.pyc
#  create mode 100644 __pycache__/tps.cpython-38.pyc
#  create mode 100644 __pycache__/train.cpython-37.pyc
#  create mode 100644 __pycache__/train.cpython-38.pyc
#  create mode 100644 __pycache__/transformation.cpython-37.pyc
#  create mode 100644 __pycache__/util.cpython-37.pyc
#  create mode 100644 __pycache__/util.cpython-38.pyc
#  create mode 100644 dataset.py
#  create mode 100644 github.ipynb
#  create mode 100644 main.py
#  create mode 100644 model.py
#  create mode 100644 "pokemon/25-belle.png\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
#  create mode 100644 "pokemon/25-libre.png\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
#  create mode 100644 "pokemon/25-phd.png\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
#  create mode 100644 "pokemon/25-pop-star.png\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
#  create mode 100644 "pokemon/25-rock-star.png\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
#  create mode 100644 "pokemon/25.png\341\204\213\341\205\264 \341\204\211\341\205\241\341\204\207\341\205\251\341\206\253"
#  create mode 100644 run.ipynb
#  create mode 100644 train.py
#  create mode 100644 transformation.py
#  create mode 100644 util.py

# %%
# !git push origin master
# Out:
# remote: Support for password authentication was removed on August 13, 2021. Please use a personal access token instead.
# remote: Please see https://github.blog/2020-12-15-token-authentication-requirements-for-git-operations/ for more information.
# fatal: Authentication failed for 'https://jangmii:429412k!@github.com/jangmii/paper-to-code-Reference-Based-Sketch-Image-Colorization.git/'
